# %% [markdown]
# # ChainOfThought, Field Descriptions & Typed Outputs

# %%
import numpy
import dspy
from dotenv import load_dotenv
load_dotenv()

lm = dspy.LM('ollama_chat/llama3.2:3b', api_base='http://localhost:11434')
dspy.configure(lm=lm)

# %%
from typing import Literal

class YesNo(dspy.Signature):
    """Answer the question. If the answer cannot be determined with confidence, say Uncertain."""

    question: str = dspy.InputField(desc="A yes/no question")
    answer: Literal["True", "False", "Uncertain"] = dspy.OutputField(desc="True, False, or Uncertain if the answer cannot be determined")

cot = dspy.ChainOfThought(YesNo)

# %%
result = cot(question="The smallest country in the second largest continent is North America.")

print("Reasoning:", result.reasoning)
print("Answer:", result.answer)
print("Type:", type(result.answer))
# Out:
# Reasoning: This statement does not make sense, as countries are typically associated with continents, and continents are typically associated with geographic areas on the surface of the Earth. A country cannot be both in North America (which is a continent) and also be considered the smallest in that continent.
# Answer: Uncertain
# Type: <class 'str'>

# %%
dspy.inspect_history(n=1)
# Out:
# [2026-08-20T13:59:05.237756]
#
# System message:
#
# Your input fields are:
# 1. `question` (str): A yes/no question
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (bool): True if yes, False if no
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## question ## ]]
# {question}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}        # note: the value you produce must be True or False
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Answer the question with a yes or no.
#
#
# User message:
#
# [[ ## question ## ]]
# Is the sky blue?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]` (must be formatted as a valid Python bool), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The color of the sky can appear blue to our eyes during the day due to a phenomenon called Rayleigh scattering, where shorter wavelengths of light (such as blue and violet) are scattered more than longer wavelengths (such as red and orange). However, the actual color of the sky can also be affected by other factors like pollution, atmospheric conditions, and time of day.
#
# [[ ## answer ## ]]
# True
#
# [[ ## completed ## ]]
